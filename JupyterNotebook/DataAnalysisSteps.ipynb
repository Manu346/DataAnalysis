# %% [markdown]
# # Data cleaning/ Analysis

# %% [markdown]
# **Step 1**
#
# - Read the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/media/manohar/Drive4/Learning/Data Science/Class/DataSets/telecom_churn_data - telecom_churn_data.csv')
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %% [markdown]
# **Step 2**
#
# - Create Categorical and numerical columns

# %% [markdown]
# since phone number column having '-' it is considered in categorical column so we can assign categorical and numerical columns after error removal

# %%
# Categorical_columns= df.select_dtypes(include=['object'])
# Numerical_columns=df.select_dtypes(exclude='object')

# %% [markdown]
# **Step 3**
#
# - Data Quick Checks
#     - Shape
#     - size
#     - len
#     - Head
#     - Tail
#     - Info

# %%
print(f'shape of the give data is {df.shape}')
print(f'size of the give data is {df.size}')
print(f'len of give data set is {len(df)}\n')
df.info()
# Out:
# shape of the give data is (2000, 16)
# size of the give data is 32000
# len of give data set is 2000
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
# ...

# %%
df.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %%
df.tail()
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 1995           no             yes               182.25                11.3
# 1996           no              no               273.45                 9.3
# 1997           no              no               128.85                15.6
# 1998           no              no               178.05                10.4
# 1999           no              no               326.70                10.3
#
#       maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# ...

# %% [markdown]
# **Step 4**
#
# - Missing value analysis

# %%
print(df.isnull().sum())
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %%
df['maximum_days_inactive'] = df['maximum_days_inactive'].interpolate()
df['gender']=df['gender'].ffill()
df['churn']=df['churn'].ffill()

# %%
print(df.isnull().sum())
# Out:
# year                      0
# customer_id               0
# phone_no                  0
# gender                    0
# age                       0
# no_of_days_subscribed     0
# multi_screen              0
# mail_subscribed           0
# weekly_mins_watched       0
# minimum_daily_mins        0
# maximum_daily_mins        0
# weekly_max_night_mins     0
# videos_watched            0
# maximum_days_inactive     0
# customer_support_calls    0
# churn                     0
# dtype: int64

# %% [markdown]
# **Step 5**
#
# - Data Quality checks or Data cleaning
#     - Eg- If some columns have punctuations or unneccesary symbols or having categorical data in numerical data

# %% [markdown]
# - Identified '-' in phone number. It can make numerical data into categorical data so joining it

# %%
a=[]
for i in df['phone_no']:
    a.append(''.join(i.split('-')))
df['phone_no']=a

# %%
df['phone_no']=df['phone_no'].astype('int64')
Categorical_columns= df.select_dtypes(include=['object'])
Numerical_columns=df.select_dtypes(exclude='object')

# %% [markdown]
# **Step 6**
#
# - Categorical column analysis
#
#     write your understanding of
#     - Frequency Table
#     - Relative Frequency
#     - Bar Chart
#     - Pie chart

# %% [markdown]
# Frequency Table

# %%
b=dict()
for i in Categorical_columns.columns:
    b[i]=df[i].value_counts()
df1=pd.DataFrame(b)
df1
# Out:
#         gender  multi_screen  mail_subscribed
# Female   935.0           NaN              NaN
# Male    1065.0           NaN              NaN
# no         NaN        1802.0           1430.0
# yes        NaN         198.0            570.0

# %% [markdown]
# Relative frequency table

# %%
c={}
for i in Categorical_columns.columns:
    # print(f'\nfrequency table for {i} is {df[i].value_counts()}')
    c[i]=df[i].value_counts(normalize=True)
df2=pd.DataFrame(c)
df2
# Out:
#         gender  multi_screen  mail_subscribed
# Female  0.4675           NaN              NaN
# Male    0.5325           NaN              NaN
# no         NaN         0.901            0.715
# yes        NaN         0.099            0.285

# %% [markdown]
# Bar chart

# %%
plt.figure(figsize=(20,5))
for i in range(len(df1.columns)):
    plt.subplot(1,3,i+1)
    sns.barplot(df[df1.columns[i]].value_counts())
plt.show()

# %% [markdown]
# pie chart

# %%
plt.figure(figsize=(20,5))
for i in range(len(df1.columns)):
    plt.subplot(1,3,i+1)
    plt.pie(df[df1.columns[i]].value_counts(),autopct='%2.0f%%',labels=df[df1.columns[i]].value_counts().index,pctdistance=0.7)
    plt.title(f'Pie chart for {df1.columns[i]}')
plt.show()

# %% [markdown]
# **Step 7**
#
# - Numerical column analysis
#
#     write your understanding
#     - Statistical summary
#     - Histogram
#     - Data Distribution

# %% [markdown]
# Statistical summary

# %%
# Numerical_columns.drop(columns='customer_id',inplace=True)
Numerical_columns.describe()
# Out:
#          year    customer_id      phone_no         age  no_of_days_subscribed  \
# count  2000.0    2000.000000  2.000000e+03  2000.00000            2000.000000
# mean   2015.0  554887.157500  3.744826e+06    38.69050              99.750000
# std       0.0  261033.690318  2.753504e+05    10.20641              39.755386
# min    2015.0  100198.000000  3.271319e+06    18.00000               1.000000
# 25%    2015.0  328634.750000  3.510754e+06    32.00000              73.000000
# 50%    2015.0  567957.500000  3.744099e+06    37.00000              99.000000
# 75%    2015.0  773280.250000  3.983954e+06    44.00000             127.000000
# max    2015.0  999961.000000  4.229964e+06    82.00000             243.000000
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          2000.000000         2000.000000         2000.000000
# mean            270.178425           10.198700           30.620780
# ...

# %% [markdown]
# Histogram

# %%
plt.figure(figsize=(30,19))
for i in range(1,len(Numerical_columns.columns)):
    plt.subplot(3,4,i)
    sns.histplot(df[Numerical_columns.columns[i]],kde=True)
    plt.title(f'Histogram for {Numerical_columns.columns[i]}')
plt.show()

# %% [markdown]
# Data Distribution

# %%
print(Numerical_columns.skew())
# Out:
# year                      0.000000
# customer_id              -0.061894
# phone_no                  0.009781
# age                       0.958224
# no_of_days_subscribed     0.149091
# weekly_mins_watched      -0.067111
# minimum_daily_mins       -0.162111
# maximum_daily_mins       -0.067104
# weekly_max_night_mins    -0.000058
# videos_watched            1.309209
# maximum_days_inactive    -0.250717
# customer_support_calls    1.128124
# churn                     2.156776
# dtype: float64

# %% [markdown]
# **Step 8**
#
# - Outlier Analysis
#
#     - Boxplot
#     - Treat the outliers

# %% [markdown]
# BoxPLot

# %%
plt.figure(figsize=(30,19))
for i in range(1,len(Numerical_columns.columns)):
    plt.subplot(3,4,i)
    sns.boxplot(df[Numerical_columns.columns[i]],orient='h')
    plt.title(f'Boxplot for {Numerical_columns.columns[i]}')
plt.show()

# %% [markdown]
# Treating outliers

# %%
# Numerical_columns.drop(columns='churn',inplace=True)
for i in range(1,len(Numerical_columns.columns)):
    q1=np.quantile(df[Numerical_columns.columns[i]],0.25)
    q3=np.quantile(df[Numerical_columns.columns[i]],0.75)
    iqr=q3-q1
    lower_bound=q1-1.5*iqr
    upper_bound=q3+1.5*iqr
    df[Numerical_columns.columns[i]]=df[Numerical_columns.columns[i]].apply(lambda x: upper_bound if x>upper_bound else lower_bound if x<lower_bound else x)
plt.figure(figsize=(30,19))
for i in range(1,len(Numerical_columns.columns)):
    plt.subplot(3,4,i)
    sns.boxplot(df[Numerical_columns.columns[i]],orient='h')
    plt.title(f'Boxplot for {Numerical_columns.columns[i]}')
plt.show()

# %% [markdown]
# **Step 9**
#
# - BiVariate and Multi Variate Analysis
#     - How one column impact other column
#     - Corelation
#     - seaborn
#     - Heatmaps ...etc

# %%
plt.figure(figsize=(30,19))
for i in range(len(Numerical_columns.columns)-1):
    plt.subplot(3,4,i+1)
    sns.scatterplot(x=df[Numerical_columns.columns[i]],y=df[Numerical_columns.columns[i+1]])
    plt.title(f'Scatter plot for {Numerical_columns.columns[i]}')
plt.show()

# %%
plt.figure(figsize=(30,19))
for i in range(1,len(Numerical_columns.columns)-1):
    plt.subplot(3,4,i)
    sns.heatmap(data=df[Numerical_columns.columns[i:i+2]].corr(),annot=True)
    plt.title(f'Heatmap for {Numerical_columns.columns[i]}')
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# **Step 10**
#
# - Convert categorical to numerical....Encoding
#     - LabelEncoder
#     - OneHotEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in Categorical_columns.columns:
    df[i]=le.fit_transform(df[i])
df
# Out:
#       year  customer_id  phone_no  gender   age  no_of_days_subscribed  \
# 0     2015       100198   4098743       0  36.0                   62.0
# 1     2015       100643   3405930       0  39.0                  149.0
# 2     2015       100756   3723750       0  62.0                  126.0
# 3     2015       101595   3314902       0  24.0                  131.0
# 4     2015       101653   3518398       0  40.0                  191.0
# ...    ...          ...       ...     ...   ...                    ...
# 1995  2015       997132   3857387       0  54.0                   75.0
# 1996  2015       998086   3839255       1  45.0                  127.0
# 1997  2015       998474   3532080       1  53.0                   94.0
# 1998  2015       998934   3597788       1  40.0                   94.0
# 1999  2015       999961   4141496       1  37.0                   73.0
#
#       multi_screen  mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %% [markdown]
# **Step 11**
#
# - Scaling
#     - Standardization
#     - Normalization

# %%
#standardization 
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
for i in Numerical_columns.columns:
    df[i]=sc.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       year  customer_id  phone_no  gender       age  no_of_days_subscribed  \
# 0      0.0    -1.742315  1.285655       0 -0.258209              -0.953242
# 1      0.0    -1.740610 -1.231089       0  0.054330               1.247948
# 2      0.0    -1.740177 -0.076562       0  2.450455               0.666024
# 3      0.0    -1.736962 -1.561761       0 -1.508361               0.792529
# 4      0.0    -1.736739 -0.822532       0  0.158509               2.310591
# ...    ...          ...       ...     ...       ...                    ...
# 1995   0.0     1.694630  0.408894       0  1.617020              -0.624328
# 1996   0.0     1.698285  0.343027       1  0.679406               0.691325
# 1997   0.0     1.699772 -0.772831       1  1.512841              -0.143609
# 1998   0.0     1.701535 -0.534137       1  0.158509              -0.143609
# 1999   0.0     1.705470  1.440961       1 -0.154029              -0.674930
#
# ...

# %%
# Normalization
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
for i in Numerical_columns.columns:
    df[i]=sc.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       year  customer_id  phone_no  gender       age  no_of_days_subscribed  \
# 0      0.0     0.000000  0.863118       0  0.409091               0.294686
# 1      0.0     0.000495  0.140418       0  0.477273               0.714976
# 2      0.0     0.000620  0.471948       0  1.000000               0.603865
# 3      0.0     0.001553  0.045463       0  0.136364               0.628019
# 4      0.0     0.001617  0.257738       0  0.500000               0.917874
# ...    ...          ...       ...     ...       ...                    ...
# 1995   0.0     0.996856  0.611350       0  0.818182               0.357488
# 1996   0.0     0.997916  0.592436       1  0.613636               0.608696
# 1997   0.0     0.998347  0.272010       1  0.795455               0.449275
# 1998   0.0     0.998859  0.340553       1  0.500000               0.449275
# 1999   0.0     1.000000  0.907716       1  0.431818               0.347826
#
# ...

# %% [markdown]
# **Step 12 (optional)**
#
# - Feature Engineering
#     - Transformation of Data

# %%
plt.figure(figsize=(30,19))
for i in range(len(df.columns)):
    plt.subplot(4,4,i+1)
    plt.hist(df[df.columns[i]],bins=20)
    plt.xlabel(df[df.columns[i]].name)
    plt.ylabel('Frequency')
